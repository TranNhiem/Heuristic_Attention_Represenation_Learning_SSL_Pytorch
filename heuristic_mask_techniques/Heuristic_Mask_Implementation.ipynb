# %% [markdown]
# <a href="https://colab.research.google.com/github/TranNhiem/Heuristic_attention_represenation_learning_ssl/blob/main/Heuristic_segmentation/Heuristic_Mask_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Implementation MASK Proposal for Natural Images
# **Our Goals**
# finding the method statisfy
# + Generalize well cross domain dataset [natural, medical images etc]
#
# + Implementation[ Simpel strategy, less computation resources requirement],
#
# + performance [generate high accurate mask genreated] dealing with multile case (Input images [1] With/Without Object,[2] Artifact Objects [3] Natural Object etc.
#
# **==> Expected Goals As Demonstration as follow in Two Figures**
# Image cite: https://arxiv.org/pdf/1904.09146.pdf
#
# ![Screenshot 2021-09-24 at 13.48.54.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2021-09-24 at 13.49.30.png](data:image/png;base64,...)

# %% [markdown]
# ## Packages & Indepencies Installation

# %% [markdown]
# ## Classifcal Machine Learning Method Implementation

# %% [markdown]
# ## Deep Learning Method Implementation
